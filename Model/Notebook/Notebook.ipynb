# %% [markdown]
# <span style="font-size:20px;">Figure A - Original features used, before encoding.</span>

# %%
from IPython.display import Image, display

display(Image(filename="Feature_List.png"))

# %% [markdown]
# <span style="font-size:20px;">Figure B - Correlation Matrix</span>

# %%
display(Image(filename="EDA_CorrelationMatrix.png"))

# %% [markdown]
# <span style="font-size:20px;">Figure C - Train/Validation/Test split of the dataset (Feature counts)</span>

# %%
display(Image(filename="Data_Split.png"))

# %% [markdown]
# <span style="font-size:20px;">Figure D - Hyperparamters tuned for RF model, and the corresponding produced RMSE value</span>

# %%
display(Image(filename="RF_Tuning_RMSE_Val.png"))

# %% [markdown]
# <span style="font-size:20px;">Figure E - Highly skewed Worldwide Revenue data</span>

# %%
display(Image(filename="EDA_WorldwideHistogram.png"))
